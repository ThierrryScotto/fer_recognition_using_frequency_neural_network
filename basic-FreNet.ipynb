# %% [markdown]
# # Importing libraries

# %%
from scipy.fftpack import dct

# %% [markdown]
# # Importing dataset

# %% [markdown]
# # DCT and CIE Layer

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# dct(dct(image.T, norm='ortho').T, norm='ortho')
